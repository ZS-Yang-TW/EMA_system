# %%
# 引入套件
from manim import *
import os

from EMA_system.template import *
from EMA_system.calculate import *

# %%
class test(addition):
    def construct(self):
        a_int_list, b_int_list, ans_int_list, carry_int_list, max_len=calculate_str(1987,1579)
        t0 = self.table_gen(a_int_list, b_int_list, ans_int_list, max_len)
        
        self.add(t0)

# %%
# 魔術命令，用來對終端機輸入指令。 
# %manim -v Warning --disable_caching -qm test
